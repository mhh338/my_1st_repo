# %% [markdown]
# # Data Collection In Machine Learning

# %%
import pandas as pd

# %% [markdown]
# 1, Sites For Downloading Datasets

# %%
# 1, kaggle
# 2, UCI Machine Learning Repository
# 3, Google Dataset Search

# %% [markdown]
# Loading The Dataset

# %%
dataset = pd.read_csv("/content/House-Price-Index-for-Boston.csv")
print(type(dataset))
dataset.head()

# %% [markdown]
# 2, Importing Datasets Through Kaggle API

# %%
# Installing kaggle library
# !pip install kaggle

# %% [markdown]
# Uploading Kaggle .JSON File

# %%
# Configuring path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing The Earthquack Dataset

# %%
# Fetching dataset from kaggle using API
# !kaggle competitions download -c LANL-Earthquake-Prediction --force

# %%
# Extracting the zipped 'LANL-Earthquake-Prediction.zip' file
from zipfile import ZipFile
LANL_file = "/content/LANL-Earthquake-Prediction.zip"

with ZipFile(LANL_file, 'r') as zip:
  zip.extractall()
  print('The LANL_file is extracted')
# Out:
# The LANL_file is extracted
